# %%
import sys
# plot 
import matplotlib.pyplot as plt  

f = open('../build/laser_NIS.txt', 'r')


laser_nis = []
for nis in f:
    laser_nis.append(nis)
plt.plot(laser_nis,'gs-')
plt.show()

# %%
import sys
# plot 
import matplotlib.pyplot as plt  

f = open('../build/laser_NIS.txt', 'r')


laser_nis = []
for nis in f:
    laser_nis.append(nis)
plt.plot(laser_nis,'gs-')
plt.show()

# %%
f = open('../build/radar_NIS.txt', 'r')


radar_nis = []
for nis in f:
    radar_nis.append(nis)
plt.plot(radar_nis,'bs-')
plt.show()

# %%
f = open('../build/radar_NIS.txt', 'r')


radar_nis = []
for nis in f:
    radar_nis.append(nis)
plt.plot(radar_nis,'bs-')
plt.show()
